# %%
import geopandas as gpd
import pandas as pd
import numpy as np

# %%
grid = gpd.read_file('./0.5 Grid/0.5.shp')
data = gpd.read_file('./final_data.gpkg')

# %%
data['row_index'] = (data['LONGITUDE']-111.95)//0.5
data['col_index'] = (-9.95-data['LATITUDE'])//0.5
data['grid_index'] = data['col_index'] + data['row_index']*69+1

# %%
#以grid_index排序
data = data.sort_values(by=['grid_index'])

# %%
#grid新设置列记录从2001年1月到2025年2月的数据
for i in range(2001, 2026):
    for j in range(1, 13):
        grid[str(i)+'-'+str(j)] = np.nan
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geodataframe.py:1819: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geodataframe.py:1819: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   super().__setitem__(key, value)
# ...

# %%
grid
# Out:
#           id    left    top   right  bottom  row_index  col_index  \
# 0        1.0  111.95  -9.95  112.45  -10.45        0.0        0.0
# 1        2.0  111.95 -10.45  112.45  -10.95        1.0        0.0
# 2        3.0  111.95 -10.95  112.45  -11.45        2.0        0.0
# 3        4.0  111.95 -11.45  112.45  -11.95        3.0        0.0
# 4        5.0  111.95 -11.95  112.45  -12.45        4.0        0.0
# ...      ...     ...    ...     ...     ...        ...        ...
# 5860  5861.0  153.95 -41.95  154.45  -42.45       64.0       84.0
# 5861  5862.0  153.95 -42.45  154.45  -42.95       65.0       84.0
# 5862  5863.0  153.95 -42.95  154.45  -43.45       66.0       84.0
# 5863  5864.0  153.95 -43.45  154.45  -43.95       67.0       84.0
# 5864  5865.0  153.95 -43.95  154.45  -44.45       68.0       84.0
#
#                                                geometry  2001-1  2001-2  ...  \
# 0     POLYGON ((111.95 -9.95, 112.45 -9.95, 112.45 -...     NaN     NaN  ...
# ...

# %%
#将data列名中类似2001-01改为2001-1，以便与grid列名对应
for i in range(2001, 2026):
    for j in range(1, 13):
        if j < 10:
            data = data.rename(columns={str(i)+'-0'+str(j):str(i)+'-'+str(j)})
        else:
            data = data.rename(columns={str(i)+'-'+str(j):str(i)+'-'+str(j)})
# Out:
#           STATION  LATITUDE  LONGITUDE  ELEVATION  \
# 256   ASN00006095  -24.3967   113.4056       16.0
# 257   ASN00006097  -26.1203   113.3975        3.0
# 261   ASN00006102  -26.1764   113.2150        4.0
# 169   ASN00005020  -22.6975   113.6747       10.0
# 210   ASN00006009  -23.1050   113.8031        6.0
# ...           ...       ...        ...        ...
# 5400  ASN00058040  -28.5451   153.4948       15.0
# 5442  ASN00058162  -28.7278   153.4622       30.0
# 5421  ASN00058103  -28.5513   153.5475        5.0
# 5428  ASN00058131  -28.8521   153.4556      140.0
# 5376  ASN00058001  -28.8528   153.5691        3.0
#
#                                     NAME  2001-1  2001-2  2001-3  2001-4  \
# 256                           QUOBBA, AS    20.0     0.0     0.0     7.0
# 257                     USELESS LOOP, AS     0.0     6.3     0.0     2.6
# 261                      STEEP POINT, AS     4.0     6.0     0.5     6.0
# ...

# %%
#data根据grid_index分组
grouped = data.groupby('grid_index')

# %%
#以grid_index为分组，计算data中2001年1月到2025年2月的数据的平均值
grouped = data.groupby('grid_index')
for i in range(2001, 2025):
    for j in range(1, 13):
        grid[str(i)+'-'+str(j)] = grouped[str(i)+'-'+str(j)].mean()
grid['2025-1'] = grouped['2025-1'].mean()
grid['2025-2'] = grouped['2025-2'].mean()

# %%
grid.to_file('./rain_data.gpkg', driver='GPKG')
# Out:
#           STATION  LATITUDE  LONGITUDE  ELEVATION  \
# 0     ASN00001001  -15.1806   127.8456        2.0
# 1     ASN00001006  -15.5100   128.1503        3.8
# 2     ASN00001007  -13.7542   126.1485        6.0
# 3     ASN00001009  -15.4875   124.5222       12.0
# 4     ASN00001010  -14.7883   126.4964      210.0
# ...           ...       ...        ...        ...
# 7560  ASN00091072  -41.4678   147.1628       67.0
# 7561  ASN00091074  -40.9911   145.0783       57.0
# 7562  ASN00091077  -41.5750   147.4508      275.0
# 7563  ASN00091079  -41.0867   145.5517      260.0
# 7564  ASN00091081  -41.3317   146.4150       60.0
#
#                               NAME  2001-01  2001-02  2001-03  2001-04  \
# 0                  OOMBULGURRI, AS      NaN      NaN      NaN      NaN
# 1                 WYNDHAM AERO, AS    268.6    193.6    266.2      2.0
# 2             TROUGHTON ISLAND, AS    248.4    121.4    164.4     61.0
# 3                     KURI BAY, AS    264.2    191.0    583.4     89.6
# ...

# %% [markdown]
# 以下是人口密度计算

# %%
pop_data = gpd.read_file('./32180_ERP_2024_SA2_GDA2020/32180_ERP_2024_SA2_GDA2020.gpkg')

# %%
pop_data.columns
# Out:
# Index(['state_code_2021', 'state_name_2021', 'gccsa_code_2021',
#        'gccsa_name_2021', 'sa4_code_2021', 'sa4_name_2021', 'sa3_code_2021',
#        'sa3_name_2021', 'sa2_code_2021', 'sa2_name_2021', 'erp_2001',
#        'erp_2002', 'erp_2003', 'erp_2004', 'erp_2005', 'erp_2006', 'erp_2007',
#        'erp_2008', 'erp_2009', 'erp_2010', 'erp_2011', 'erp_2012', 'erp_2013',
#        'erp_2014', 'erp_2015', 'erp_2016', 'erp_2017', 'erp_2018', 'erp_2019',
#        'erp_2020', 'erp_2021', 'erp_2022', 'erp_2023', 'erp_2024',
#        'erp_change_number_2023_24', 'erp_change_per_cent_2023_24', 'area_km2',
#        'pop_density_2024_people_per_km2', 'births_2021_22', 'deaths_2021_22',
#        'natural_increase_2021_22', 'internal_arrivals_2021_22',
#        'internal_departures_2021_22', 'net_internal_migration_2021_22',
#        'overseas_arrivals_2021_22', 'overseas_departures_2021_22',
#        'net_overseas_migration_2021_22', 'births_2022_23', 'deaths_2022_23',
# ...

# %%
pop_data.drop(columns=['erp_change_number_2023_24', 'erp_change_per_cent_2023_24', 
       'pop_density_2024_people_per_km2', 'births_2021_22', 'deaths_2021_22',
       'natural_increase_2021_22', 'internal_arrivals_2021_22',
       'internal_departures_2021_22', 'net_internal_migration_2021_22',
       'overseas_arrivals_2021_22', 'overseas_departures_2021_22',
       'net_overseas_migration_2021_22', 'births_2022_23', 'deaths_2022_23',
       'natural_increase_2022_23', 'internal_arrivals_2022_23',
       'internal_departures_2022_23', 'net_internal_migration_2022_23',
       'overseas_arrivals_2022_23', 'overseas_departures_2022_23',
       'net_overseas_migration_2022_23', 'births_2023_24', 'deaths_2023_24',
       'natural_increase_2023_24', 'internal_arrivals_2023_24',
       'internal_departures_2023_24', 'net_internal_migration_2023_24',
       'overseas_arrivals_2023_24', 'overseas_departures_2023_24',
       'net_overseas_migration_2023_24', 'sa3_code_2021',
       'sa3_name_2021', 'sa2_code_2021', 'sa2_name_2021',], inplace=True)

# %%
#计算pop_data中每个地区的人口密度
pop_dense_data = pop_data.copy()
for i in range(2001, 2025):
    pop_dense_data['erp_'+str(i)] = pop_dense_data['erp_'+str(i)] / pop_dense_data['area_km2']

# %%
#画出grid中ERP_dense2024的直方图
import matplotlib.pyplot as plt
plt.hist(grid[grid['ERP_dense2024']!=0]['ERP_dense2024'])
plt.show()

# %%
grid
# Out:
# nan

# %%
grid[grid['ERP_dense2024']!=grid['ERP_dense2024'][0]]['ERP_dense2024']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 5860   NaN
# 5861   NaN
# 5862   NaN
# 5863   NaN
# 5864   NaN
# Name: ERP_dense2024, Length: 5865, dtype: float64

# %%
pop_dense_data.head()
# Out:
#    state_code_2021  state_name_2021 gccsa_code_2021 gccsa_name_2021  \
# 0                1  New South Wales           1RNSW     Rest of NSW
# 1                1  New South Wales           1RNSW     Rest of NSW
# 2                1  New South Wales           1RNSW     Rest of NSW
# 3                1  New South Wales           1RNSW     Rest of NSW
# 4                1  New South Wales           1RNSW     Rest of NSW
#
#    sa4_code_2021   sa4_name_2021     erp_2001     erp_2002     erp_2003  \
# 0            101  Capital Region     0.807406     0.822326     0.829347
# 1            101  Capital Region  1307.411386  1317.436448  1326.602220
# 2            101  Capital Region  2040.529189  1997.690046  1999.580008
# 3            101  Capital Region   301.848776   313.230589   324.458595
# 4            101  Capital Region   689.223974   750.065814   810.615146
#
#       erp_2004  ...     erp_2017     erp_2018     erp_2019     erp_2020  \
# ...

# %%
grid = gpd.read_file('./0.5 Grid/0.5.shp')
pop_dense_data.to_crs(epsg=3577, inplace=True)
grid.to_crs(epsg=3577, inplace=True)

# %%
grid["grid_area"] = grid.geometry.area

# %%
intersection = gpd.overlay(grid, pop_dense_data, how='intersection')

# %%
intersection.to_crs(epsg=3577, inplace=True)
grid.to_crs(epsg=3577, inplace=True)

# %%
intersection["int_area"] = intersection.geometry.area
grid["grid_area"] = grid.geometry.area

# %%
target_columns = []
for i in range(2001, 2025):
    intersection["ERP_dense"+str(i)] = intersection["erp_"+str(i)] * (intersection["int_area"] / intersection["grid_area"])
    target_columns.append("ERP_dense"+str(i))
weighted_density = intersection.groupby("id")[target_columns].sum().reset_index()

# %%
#检测
g_area_1 = intersection[intersection['id'] == 4948]['int_area'].sum()
g_area_2 = intersection[intersection['id'] == 4948]['grid_area'].mean()
g_area_1/g_area_2
# Out:
# 0.9999999999999976

# %%
grid = grid.merge(weighted_density, on="id", how="left")

# %%
grid.to_file('./pop_dense_data.gpkg', driver='GPKG')

# %%
grid.head()
# Out:
#     id    left    top   right  bottom  row_index  col_index  \
# 0  1.0  111.95  -9.95  112.45  -10.45        0.0        0.0
# 1  2.0  111.95 -10.45  112.45  -10.95        1.0        0.0
# 2  3.0  111.95 -10.95  112.45  -11.45        2.0        0.0
# 3  4.0  111.95 -11.45  112.45  -11.95        3.0        0.0
# 4  5.0  111.95 -11.95  112.45  -12.45        4.0        0.0
#
#                                             geometry     grid_area  \
# 0  POLYGON ((-2252126.959 -1219934.805, -2196408....  3.029889e+09
# 1  POLYGON ((-2243713.849 -1273101.108, -2188203....  3.025142e+09
# 2  POLYGON ((-2235282.329 -1326383.756, -2179981....  3.020170e+09
# 3  POLYGON ((-2226832.82 -1379780.084, -2171740.5...  3.014974e+09
# 4  POLYGON ((-2218365.75 -1433287.393, -2163482.9...  3.009553e+09
#
#    ERP_dense2001  ...  ERP_dense2015  ERP_dense2016  ERP_dense2017  \
# 0            NaN  ...            NaN            NaN            NaN
# ...
